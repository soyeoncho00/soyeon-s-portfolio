# %%
import pandas as pd
import seaborn as sns
import FinanceDataReader as fdr

# %%
from bs4 import BeautifulSoup
import requests


###lg 화학 분석
if __name__ == '__main__':
    url = 'https://finance.naver.com/item/sise_day.nhn?code=051910&page=1'
    req = requests.get(url, headers={'User-agent': 'Mozilla/5.0'}).text

    html = BeautifulSoup(req, 'lxml')
    pgrr = html.find('td', class_='pgRR')
    s = str(pgrr.a['href']).split('=')
    last_page = s[-1]

last_page
#마지막 페이지가 522
# Out:
# '522'

# %%
df = pd.DataFrame()
sise_url = 'https://finance.naver.com/item/sise_day.nhn?code=051910'

for page in range(1, int(last_page)+1) :
  page_url = '{}&page={}'.format(sise_url,page)
  df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
  
df = df.dropna()
df
# Out:
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# ...
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
# C:\Users\ssoyeon\AppData\Local\Temp\ipykernel_22032\3774056908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_html(requests.get(page_url,headers={'User-agent': 'Mozilla/5.0'}).text)[0])
#             날짜        종가      전일비        시가        고가        저가        거래량
# 1   2022.05.25  534000.0   5000.0  549000.0  550000.0  534000.0   197901.0
# 2   2022.05.24  539000.0   4000.0  544000.0  551000.0  537000.0   198053.0
# 3   2022.05.23  543000.0   2000.0  547000.0  555000.0  538000.0   270359.0
# 4   2022.05.20  545000.0  43000.0  505000.0  546000.0  505000.0   531053.0
# 5   2022.05.19  502000.0  10000.0  495000.0  507000.0  495000.0   200969.0
# ..         ...       ...      ...       ...       ...       ...        ...
# 11  2001.05.02   13000.0    200.0   12900.0   13250.0   12650.0   851580.0
# 12  2001.04.30   12800.0    100.0   12450.0   12850.0   12450.0   803230.0
# 13  2001.04.27   12700.0    300.0   12150.0   12800.0   12000.0   854340.0
# 1   2001.04.26   12400.0    600.0   12600.0   12950.0   12300.0  1197840.0
# 2   2001.04.25   13000.0      0.0   14500.0   14500.0   12350.0  3094940.0
#
# [5212 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5212 entries, 1 to 2
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      5212 non-null   object
#  1   종가      5212 non-null   float64
#  2   전일비     5212 non-null   float64
#  3   시가      5212 non-null   float64
#  4   고가      5212 non-null   float64
#  5   저가      5212 non-null   float64
#  6   거래량     5212 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 325.8+ KB

# %%
df["날짜"] = pd.to_datetime(df['날짜'])
df.set_index('날짜', inplace = True)
df = df.sort_values('날짜')
df
# Out:
#                   종가      전일비        시가        고가        저가        거래량
# 날짜
# 2001-04-25   13000.0      0.0   14500.0   14500.0   12350.0  3094940.0
# 2001-04-26   12400.0    600.0   12600.0   12950.0   12300.0  1197840.0
# 2001-04-27   12700.0    300.0   12150.0   12800.0   12000.0   854340.0
# 2001-04-30   12800.0    100.0   12450.0   12850.0   12450.0   803230.0
# 2001-05-02   13000.0    200.0   12900.0   13250.0   12650.0   851580.0
# ...              ...      ...       ...       ...       ...        ...
# 2022-05-19  502000.0  10000.0  495000.0  507000.0  495000.0   200969.0
# 2022-05-20  545000.0  43000.0  505000.0  546000.0  505000.0   531053.0
# 2022-05-23  543000.0   2000.0  547000.0  555000.0  538000.0   270359.0
# 2022-05-24  539000.0   4000.0  544000.0  551000.0  537000.0   198053.0
# 2022-05-25  534000.0   5000.0  549000.0  550000.0  534000.0   197901.0
#
# [5212 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16, 9))

plt.title("LG CHEMICAL STOCK PRICE")
plt.xlabel("time")
plt.ylabel("price")
plt.grid()
plt.plot(df['종가'],label = "close")
plt.show()

# %%
df.isnull().sum()
# Out:
# 종가     0
# 전일비    0
# 시가     0
# 고가     0
# 저가     0
# 거래량    0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

scale_cols = ['시가','고가','저가','종가','거래량']
scaled_df = scaler.fit_transform(df[scale_cols])
#fit_transform 함수는 넘파이를 리턴
scaled_df = pd.DataFrame(scaled_df, columns = scale_cols)
#정규화된 새로운 dataframe 생성시켜야함

scaled_df

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scale_cols = ['시가','고가','저가','종가','거래량']
scaled_df = scaler.fit_transform(df[scale_cols])
scaled_df = pd.DataFrame(scaled_df, columns = scale_cols)
scaled_df
# Out:
#             시가        고가        저가        종가       거래량
# 0     0.014258  0.013810  0.012289  0.000591  0.775494
# 1     0.012389  0.012333  0.012239  0.000000  0.300141
# 2     0.011947  0.012190  0.011940  0.000295  0.214071
# 3     0.012242  0.012238  0.012388  0.000394  0.201264
# 4     0.012684  0.012619  0.012587  0.000591  0.213379
# ...        ...       ...       ...       ...       ...
# 5207  0.486726  0.482857  0.492537  0.482080  0.050356
# 5208  0.496559  0.520000  0.502488  0.524419  0.133065
# 5209  0.537856  0.528571  0.535323  0.522450  0.067743
# 5210  0.534907  0.524762  0.534328  0.518511  0.049626
# 5211  0.539823  0.523810  0.531343  0.513588  0.049588
#
# [5212 rows x 5 columns]

# %%
window_size = 20
TEST_SIZE = 200

# %%
train = scaled_df[:-TEST_SIZE]
test = scaled_df[-TEST_SIZE:]

# %%
len(df), len(train), len(test)
# Out:
# (5212, 5012, 200)

# %%
import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

# %%
scaled_df.columns
# Out:
# Index(['시가', '고가', '저가', '종가', '거래량'], dtype='object')

# %%
feature_cols = ['시가', '고가', '저가', '거래량']
label_cols = ['종가']


train_feature = train[feature_cols]
train_label = train[label_cols]

train_feature, train_label = make_dataset(train_feature, train_label,20)

test_feature = test[feature_cols]
test_label = test[label_cols]

test_feature, test_label = make_dataset(test_feature, test_label, 20)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(train_feature, train_label, test_size = 0.3)
print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (3494, 20, 4) (1498, 20, 4)
# (3494, 1) (1498, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense,GRU
from keras.callbacks import EarlyStopping, ModelCheckpoint

model = Sequential()
model.add(GRU(16, activation="relu",input_shape=(train_feature.shape[1], train_feature.shape[2])))
model.add(Dense(1))

# %%
model.compile(loss='mse', optimizer='adam')
early_stop = EarlyStopping(monitor='val_loss', patience=10)

# %%
history = model.fit(x_train, y_train, 
                    epochs=200, 
                    batch_size=16,
                    validation_data=(x_test, y_test), 
                    callbacks=[early_stop])
# Out:
# Epoch 1/200
# 219/219 [==============================] - 8s 17ms/step - loss: 0.0026 - val_loss: 1.5688e-04
# Epoch 2/200
# 219/219 [==============================] - 3s 16ms/step - loss: 1.4414e-04 - val_loss: 1.2755e-04
# Epoch 3/200
# 219/219 [==============================] - 4s 16ms/step - loss: 1.2663e-04 - val_loss: 1.2150e-04
# Epoch 4/200
# 219/219 [==============================] - 4s 18ms/step - loss: 1.2675e-04 - val_loss: 1.1777e-04
# Epoch 5/200
# 219/219 [==============================] - 4s 20ms/step - loss: 1.2314e-04 - val_loss: 1.2314e-04
# Epoch 6/200
# 219/219 [==============================] - 3s 16ms/step - loss: 1.2500e-04 - val_loss: 1.3157e-04
# Epoch 7/200
# 219/219 [==============================] - 3s 16ms/step - loss: 1.2130e-04 - val_loss: 1.3428e-04
# Epoch 8/200
# 219/219 [==============================] - 3s 15ms/step - loss: 1.2582e-04 - val_loss: 1.1053e-04
# Epoch 9/200
# 219/219 [==============================] - 3s 14ms/step - loss: 1.2359e-04 - val_loss: 1.1463e-04
# Epoch 10/200
# 219/219 [==============================] - 3s 15ms/step - loss: 1.1825e-04 - val_loss: 1.0939e-04
# Epoch 11/200
# 219/219 [==============================] - 3s 14ms/step - loss: 1.1564e-04 - val_loss: 1.2309e-04
# Epoch 12/200
# 219/219 [==============================] - 3s 13ms/step - loss: 1.1556e-04 - val_loss: 1.0455e-04
# Epoch 13/200
# 219/219 [==============================] - 3s 15ms/step - loss: 1.1192e-04 - val_loss: 1.0343e-04
# Epoch 14/200
# 219/219 [==============================] - 3s 13ms/step - loss: 1.1415e-04 - val_loss: 1.1101e-04
# Epoch 15/200
# 219/219 [==============================] - 3s 13ms/step - loss: 1.1431e-04 - val_loss: 9.8834e-05
# Epoch 16/200
# 219/219 [==============================] - 3s 13ms/step - loss: 1.1052e-04 - val_loss: 9.9335e-05
# Epoch 17/200
# 219/219 [==============================] - 3s 13ms/step - loss: 1.1356e-04 - val_loss: 1.1927e-04
# Epoch 18/200
# 219/219 [==============================] - 3s 16ms/step - loss: 1.1141e-04 - val_loss: 1.0913e-04
# Epoch 19/200
# 219/219 [==============================] - 3s 14ms/step - loss: 1.1154e-04 - val_loss: 1.0412e-04
# Epoch 20/200
# 219/219 [==============================] - 3s 13ms/step - loss: 1.0673e-04 - val_loss: 1.2532e-04
# Epoch 21/200
# 219/219 [==============================] - 3s 13ms/step - loss: 1.0670e-04 - val_loss: 1.3016e-04
# Epoch 22/200
# 219/219 [==============================] - 3s 14ms/step - loss: 1.1137e-04 - val_loss: 1.0302e-04
# Epoch 23/200
# 219/219 [==============================] - 4s 18ms/step - loss: 1.0572e-04 - val_loss: 9.6323e-05
# Epoch 24/200
# 219/219 [==============================] - 3s 14ms/step - loss: 1.1043e-04 - val_loss: 1.2479e-04
# Epoch 25/200
# 219/219 [==============================] - 3s 13ms/step - loss: 1.1064e-04 - val_loss: 1.0190e-04
# Epoch 26/200
# 219/219 [==============================] - 3s 14ms/step - loss: 1.1174e-04 - val_loss: 1.4747e-04
# Epoch 27/200
# 219/219 [==============================] - 4s 17ms/step - loss: 1.1008e-04 - val_loss: 9.3948e-05
# Epoch 28/200
# 219/219 [==============================] - 4s 17ms/step - loss: 1.0830e-04 - val_loss: 1.3840e-04
# Epoch 29/200
# 219/219 [==============================] - 3s 16ms/step - loss: 1.0645e-04 - val_loss: 9.1580e-05
# Epoch 30/200
# 219/219 [==============================] - 3s 15ms/step - loss: 1.1136e-04 - val_loss: 1.2586e-04
# Epoch 31/200
# 219/219 [==============================] - 3s 14ms/step - loss: 1.0718e-04 - val_loss: 1.2396e-04
# Epoch 32/200
# 219/219 [==============================] - 3s 15ms/step - loss: 1.0520e-04 - val_loss: 9.5463e-05
# Epoch 33/200
# 219/219 [==============================] - 5s 22ms/step - loss: 1.0672e-04 - val_loss: 1.0674e-04
# Epoch 34/200
# 219/219 [==============================] - 4s 18ms/step - loss: 1.0346e-04 - val_loss: 1.1467e-04
# Epoch 35/200
# 219/219 [==============================] - 4s 17ms/step - loss: 1.0905e-04 - val_loss: 1.1354e-04
# Epoch 36/200
# 219/219 [==============================] - 4s 18ms/step - loss: 9.8297e-05 - val_loss: 9.4136e-05
# Epoch 37/200
# 219/219 [==============================] - 5s 22ms/step - loss: 1.0259e-04 - val_loss: 1.2044e-04
# Epoch 38/200
# 219/219 [==============================] - 4s 18ms/step - loss: 1.0528e-04 - val_loss: 1.2540e-04
# Epoch 39/200
# 219/219 [==============================] - 4s 17ms/step - loss: 1.0893e-04 - val_loss: 9.0793e-05
# Epoch 40/200
# 219/219 [==============================] - 4s 18ms/step - loss: 9.7483e-05 - val_loss: 1.3107e-04
# Epoch 41/200
# 219/219 [==============================] - 4s 20ms/step - loss: 1.0368e-04 - val_loss: 1.0707e-04
# Epoch 42/200
# 219/219 [==============================] - 3s 15ms/step - loss: 9.8916e-05 - val_loss: 8.9323e-05
# Epoch 43/200
# 219/219 [==============================] - 3s 15ms/step - loss: 1.0346e-04 - val_loss: 9.8156e-05
# Epoch 44/200
# 219/219 [==============================] - 4s 19ms/step - loss: 1.0266e-04 - val_loss: 9.8786e-05
# Epoch 45/200
# 219/219 [==============================] - 4s 18ms/step - loss: 1.0295e-04 - val_loss: 1.2617e-04
# Epoch 46/200
# 219/219 [==============================] - 3s 16ms/step - loss: 9.9465e-05 - val_loss: 9.4769e-05
# Epoch 47/200
# 219/219 [==============================] - 3s 14ms/step - loss: 9.8503e-05 - val_loss: 8.7868e-05
# Epoch 48/200
# 219/219 [==============================] - 3s 15ms/step - loss: 9.7206e-05 - val_loss: 9.8896e-05
# Epoch 49/200
# 219/219 [==============================] - 3s 15ms/step - loss: 9.7904e-05 - val_loss: 8.9186e-05
# Epoch 50/200
# 219/219 [==============================] - 4s 17ms/step - loss: 1.0122e-04 - val_loss: 1.2624e-04
# Epoch 51/200
# 219/219 [==============================] - 3s 14ms/step - loss: 1.0167e-04 - val_loss: 9.4688e-05
# Epoch 52/200
# 219/219 [==============================] - 3s 14ms/step - loss: 9.6036e-05 - val_loss: 9.5005e-05
# Epoch 53/200
# 219/219 [==============================] - 3s 16ms/step - loss: 9.6069e-05 - val_loss: 1.0785e-04
# Epoch 54/200
# 219/219 [==============================] - 4s 18ms/step - loss: 1.0498e-04 - val_loss: 9.6532e-05
# Epoch 55/200
# 219/219 [==============================] - 4s 16ms/step - loss: 1.0281e-04 - val_loss: 9.4622e-05
# Epoch 56/200
# 219/219 [==============================] - 3s 14ms/step - loss: 9.6528e-05 - val_loss: 8.7259e-05
# Epoch 57/200
# 219/219 [==============================] - 3s 14ms/step - loss: 9.7278e-05 - val_loss: 1.2552e-04
# Epoch 58/200
# 219/219 [==============================] - 3s 14ms/step - loss: 1.0299e-04 - val_loss: 1.3706e-04
# Epoch 59/200
# 219/219 [==============================] - 4s 17ms/step - loss: 9.7849e-05 - val_loss: 1.0857e-04
# Epoch 60/200
# 219/219 [==============================] - 4s 16ms/step - loss: 9.8685e-05 - val_loss: 1.0842e-04
# Epoch 61/200
# 219/219 [==============================] - 4s 16ms/step - loss: 9.7061e-05 - val_loss: 1.1078e-04
# Epoch 62/200
# 219/219 [==============================] - 3s 15ms/step - loss: 9.7276e-05 - val_loss: 8.6595e-05
# Epoch 63/200
# 219/219 [==============================] - 3s 14ms/step - loss: 9.8762e-05 - val_loss: 1.2476e-04
# Epoch 64/200
# 219/219 [==============================] - 4s 17ms/step - loss: 9.9368e-05 - val_loss: 1.1085e-04
# Epoch 65/200
# 219/219 [==============================] - 3s 13ms/step - loss: 9.4735e-05 - val_loss: 8.6100e-05
# Epoch 66/200
# 219/219 [==============================] - 3s 14ms/step - loss: 9.4120e-05 - val_loss: 8.6448e-05
# Epoch 67/200
# 219/219 [==============================] - 3s 15ms/step - loss: 9.6116e-05 - val_loss: 8.7362e-05
# Epoch 68/200
# 219/219 [==============================] - 3s 14ms/step - loss: 9.3922e-05 - val_loss: 8.7761e-05
# Epoch 69/200
# 219/219 [==============================] - 4s 20ms/step - loss: 9.0096e-05 - val_loss: 9.6435e-05
# Epoch 70/200
# 219/219 [==============================] - 4s 18ms/step - loss: 9.5127e-05 - val_loss: 9.5825e-05
# Epoch 71/200
# 219/219 [==============================] - 3s 14ms/step - loss: 9.3073e-05 - val_loss: 9.3223e-05
# Epoch 72/200
# 219/219 [==============================] - 3s 13ms/step - loss: 9.1302e-05 - val_loss: 9.2906e-05
# Epoch 73/200
# 219/219 [==============================] - 3s 14ms/step - loss: 9.0061e-05 - val_loss: 1.0064e-04
# Epoch 74/200
# 219/219 [==============================] - 3s 15ms/step - loss: 9.2758e-05 - val_loss: 1.0197e-04
# Epoch 75/200
# 219/219 [==============================] - 3s 13ms/step - loss: 9.7954e-05 - val_loss: 8.7651e-05

# %%
pred = model.predict(test_feature)

plt.figure(figsize = (16,9))
plt.xlabel("time")
plt.ylabel("price")
plt.plot(test_label, label="actual")
plt.plot(pred, label="prediction")
plt.grid()
plt.legend(loc="best")
plt.show()
# Out:
# 6/6 [==============================] - 0s 4ms/step

# %%
from keras.models import Sequential
from keras.layers import Dense,GRU
from keras.callbacks import EarlyStopping, ModelCheckpoint

model = Sequential()
model.add(GRU(16, activation="tanh",input_shape=(train_feature.shape[1], train_feature.shape[2])))
model.add(Dense(1))

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
early_stop = EarlyStopping(monitor='val_loss', patience=10)

# %%
history = model.fit(x_train, y_train, 
                    epochs=200, 
                    batch_size=16,
                    validation_data=(x_test, y_test), 
                    callbacks=[early_stop])
# Out:
# Epoch 1/200
# 219/219 [==============================] - 9s 23ms/step - loss: 5.5821e-04 - val_loss: 1.3650e-04
# Epoch 2/200
# 219/219 [==============================] - 3s 16ms/step - loss: 1.3101e-04 - val_loss: 1.5594e-04
# Epoch 3/200
# 219/219 [==============================] - 3s 15ms/step - loss: 1.2487e-04 - val_loss: 2.0483e-04
# Epoch 4/200
# 219/219 [==============================] - 3s 15ms/step - loss: 1.2798e-04 - val_loss: 1.1441e-04
# Epoch 5/200
# 219/219 [==============================] - 4s 20ms/step - loss: 1.3209e-04 - val_loss: 1.1154e-04
# Epoch 6/200
# 219/219 [==============================] - 4s 21ms/step - loss: 1.2122e-04 - val_loss: 1.2633e-04
# Epoch 7/200
# 219/219 [==============================] - 3s 16ms/step - loss: 1.1882e-04 - val_loss: 1.1060e-04
# Epoch 8/200
# 219/219 [==============================] - 3s 16ms/step - loss: 1.1672e-04 - val_loss: 1.1412e-04
# Epoch 9/200
# 219/219 [==============================] - 4s 17ms/step - loss: 1.1528e-04 - val_loss: 1.5304e-04
# Epoch 10/200
# 219/219 [==============================] - 4s 18ms/step - loss: 1.1463e-04 - val_loss: 1.8398e-04
# Epoch 11/200
# 219/219 [==============================] - 3s 16ms/step - loss: 1.2076e-04 - val_loss: 1.2598e-04
# Epoch 12/200
# 219/219 [==============================] - 3s 16ms/step - loss: 1.1195e-04 - val_loss: 1.3399e-04
# Epoch 13/200
# 219/219 [==============================] - 4s 16ms/step - loss: 1.2328e-04 - val_loss: 1.0248e-04
# Epoch 14/200
# 219/219 [==============================] - 4s 19ms/step - loss: 1.1306e-04 - val_loss: 1.2365e-04
# Epoch 15/200
# 219/219 [==============================] - 4s 17ms/step - loss: 1.1874e-04 - val_loss: 1.0961e-04
# Epoch 16/200
# 219/219 [==============================] - 4s 16ms/step - loss: 1.2521e-04 - val_loss: 1.0516e-04
# Epoch 17/200
# 219/219 [==============================] - 4s 16ms/step - loss: 1.1052e-04 - val_loss: 1.0720e-04
# Epoch 18/200
# 219/219 [==============================] - 4s 18ms/step - loss: 1.0983e-04 - val_loss: 1.0843e-04
# Epoch 19/200
# 219/219 [==============================] - 4s 18ms/step - loss: 1.1300e-04 - val_loss: 1.6227e-04
# Epoch 20/200
# 219/219 [==============================] - 4s 16ms/step - loss: 1.1167e-04 - val_loss: 1.1139e-04
# Epoch 21/200
# 219/219 [==============================] - 4s 16ms/step - loss: 1.1945e-04 - val_loss: 1.1268e-04
# Epoch 22/200
# 219/219 [==============================] - 4s 18ms/step - loss: 1.1248e-04 - val_loss: 1.0910e-04
# Epoch 23/200
# 219/219 [==============================] - 4s 18ms/step - loss: 1.0804e-04 - val_loss: 1.0438e-04

# %%
pred = model.predict(test_feature)

plt.figure(figsize = (16,9))
plt.xlabel("time")
plt.ylabel("price")
plt.plot(test_label, label="actual")
plt.plot(pred, label="prediction")
plt.grid()
plt.legend(loc="best")
plt.show()
# Out:
# 6/6 [==============================] - 1s 4ms/step
