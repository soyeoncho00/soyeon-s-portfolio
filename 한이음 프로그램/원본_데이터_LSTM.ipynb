# %% [markdown]
# ### LSTM 을 활용한 주가 예측 모델
# ##### 원본 데이터 사용

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
import datetime as dt


# %matplotlib inline
warnings.filterwarnings('ignore')

# %% [markdown]
# sqlite DB에서 데이터 불러오기

# %%
import sqlite3
con = sqlite3.connect(r"C:\Users\구남이\OneDrive\바탕 화면\활동들\한이음 멘토링\stock.db")
df = pd.read_sql("SELECT * FROM '039490'", con, index_col=None)
df.rename(columns={'index':'date'}, inplace=True)
df = df.set_index('date')
df.index = pd.DatetimeIndex(df.index)
df.sort_index(ascending=True, inplace=True)
df
# Out:
#              open   high    low  close   volume
# date
# 2004-04-23   6076   6799   5353   5353  1415109
# 2004-04-26   5436   5741   5261   5398   343283
# 2004-04-27   5452   5482   5033   5063   299489
# 2004-04-28   5071   5452   4995   5444   182604
# 2004-04-29   5117   5436   5025   5101   109911
# ...           ...    ...    ...    ...      ...
# 2022-05-11  87500  87500  85500  85800   108071
# 2022-05-12  84700  85300  82700  83200   104007
# 2022-05-13  84000  87400  83500  85800    86525
# 2022-05-16  86900  87600  85700  85900    55383
# 2022-05-17  85000  87600  85000  87600    55677
#
# [4471 rows x 5 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop('close', axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop('close', axis=1).columns)

# %%
# 타켓 스케일링
scaler1 = MinMaxScaler()
scaled_df['close'] = scaler1.fit_transform(df['close'].values.reshape(-1,1))

# %%
scaled_df
# Out:
#           open      high       low    volume     close
# 0     0.022741  0.026226  0.019066  1.000000  0.018324
# 1     0.018743  0.019815  0.018467  0.241077  0.018606
# 2     0.018842  0.018245  0.016982  0.210068  0.016507
# 3     0.016462  0.018063  0.016734  0.127305  0.018894
# 4     0.016750  0.017967  0.016930  0.075834  0.016745
# ...        ...       ...       ...       ...       ...
# 4466  0.531437  0.515237  0.540941  0.074531  0.522470
# 4467  0.513944  0.501906  0.522709  0.071653  0.506176
# 4468  0.509571  0.514631  0.527918  0.059275  0.522470
# 4469  0.527689  0.515843  0.542243  0.037224  0.523096
# 4470  0.515819  0.515843  0.537685  0.037433  0.533750
#
# [4471 rows x 5 columns]

# %%
scaled_df.drop('close', 1)
# Out:
#         open    high     low  volume
# 0    0.02274 0.02623 0.01907 1.00000
# 1    0.01874 0.01981 0.01847 0.24108
# 2    0.01884 0.01825 0.01698 0.21007
# 3    0.01646 0.01806 0.01673 0.12731
# 4    0.01675 0.01797 0.01693 0.07583
# ...      ...     ...     ...     ...
# 4466 0.53144 0.51524 0.54094 0.07453
# 4467 0.51394 0.50191 0.52271 0.07165
# 4468 0.50957 0.51463 0.52792 0.05928
# 4469 0.52769 0.51584 0.54224 0.03722
# 4470 0.51582 0.51584 0.53769 0.03743
#
# [4471 rows x 4 columns]

# %%
scaled_df['close']
# Out:
# 0      0.01832
# 1      0.01861
# 2      0.01651
# 3      0.01889
# 4      0.01674
#          ...
# 4466   0.52247
# 4467   0.50618
# 4468   0.52247
# 4469   0.52310
# 4470   0.53375
# Name: close, Length: 4471, dtype: float64

# %%
#train,test 분할
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(scaled_df.drop('close', 1), scaled_df['close'], test_size=0.3, random_state=0, shuffle=False)

# %%
# tensorflow dataset을 활용한 시퀀스 데이터셋 구성
import tensorflow as tf
def windowed_dataset(series, window_size, batch_size, shuffle):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    if shuffle:
        ds = ds.shuffle(1000)
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    return ds.batch(batch_size).prefetch(1)

# %%
# hyper parameter 정의 
WINDOW_SIZE=20
BATCH_SIZE=32

# %%
# trian_data는 학습용 데이터셋, test_data는 검증용 데이터셋
train_data = windowed_dataset(y_train, WINDOW_SIZE, BATCH_SIZE, True)
test_data = windowed_dataset(y_test, WINDOW_SIZE, BATCH_SIZE, False)

# %%
 # 모델 생성
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, Lambda
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

model = Sequential([
    # 1차원 feature map 생성
    Conv1D(filters=32, kernel_size=5,
        padding="causal",
        #활성화함수를 relu로 정의
        activation="relu",
        input_shape=[WINDOW_SIZE, 1]),
    # LSTM
    LSTM(16, activation='tanh'),    
    Dense(16, activation="relu"),
    Dense(1)])

loss = Huber()
optimizer = Adam(0.005) ##3compile 시 optimizer는 adam으로 사용
model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])

earlystopping = EarlyStopping(monitor='val_loss', patience=10)

filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename, 
                            save_weights_only=True,
                            save_best_only=True, 
                            monitor='val_loss',
                            verbose=1)

# %%
# 모델 학습
history = model.fit(train_data, 
                validation_data=(test_data), 
                epochs=50,   #50번 학습
                callbacks=[checkpoint, earlystopping])
# Out:
# Epoch 1/50
# 98/98 [==============================] - 13s 69ms/step - loss: 0.0011 - mse: 0.0021 - val_loss: 0.0024 - val_mse: 0.0048
#
# Epoch 00001: val_loss improved from inf to 0.00241, saving model to tmp\ckeckpointer.ckpt
# Epoch 2/50
# 98/98 [==============================] - 6s 57ms/step - loss: 1.6764e-04 - mse: 3.3528e-04 - val_loss: 6.8087e-04 - val_mse: 0.0014 1.6
#
# Epoch 00002: val_loss improved from 0.00241 to 0.00068, saving model to tmp\ckeckpointer.ckpt
# Epoch 3/50
# 98/98 [==============================] - 4s 34ms/step - loss: 1.4168e-04 - mse: 2.8337e-04 - val_loss: 5.1136e-04 - val_mse: 0.0010
#
# Epoch 00003: val_loss improved from 0.00068 to 0.00051, saving model to tmp\ckeckpointer.ckpt
# Epoch 4/50
# 98/98 [==============================] - 8s 82ms/step - loss: 1.1717e-04 - mse: 2.3434e-04 - val_loss: 4.3884e-04 - val_mse: 8.7767e-04
#
# Epoch 00004: val_loss improved from 0.00051 to 0.00044, saving model to tmp\ckeckpointer.ckpt
# Epoch 5/50
# 98/98 [==============================] - 4s 41ms/step - loss: 1.1401e-04 - mse: 2.2802e-04 - val_loss: 6.3515e-04 - val_mse: 0.0013
#
# Epoch 00005: val_loss did not improve from 0.00044
# Epoch 6/50
# 98/98 [==============================] - 4s 36ms/step - loss: 1.0694e-04 - mse: 2.1388e-04 - val_loss: 4.0630e-04 - val_mse: 8.1259e-04
#
# Epoch 00006: val_loss improved from 0.00044 to 0.00041, saving model to tmp\ckeckpointer.ckpt
# Epoch 7/50
# 98/98 [==============================] - 4s 35ms/step - loss: 7.7771e-05 - mse: 1.5554e-04 - val_loss: 6.7294e-04 - val_mse: 0.00131s - loss: 8.3584e-
#
# Epoch 00007: val_loss did not improve from 0.00041
# Epoch 8/50
# 98/98 [==============================] - 4s 35ms/step - loss: 8.9488e-05 - mse: 1.7898e-04 - val_loss: 3.4389e-04 - val_mse: 6.8777e-04
#
# Epoch 00008: val_loss improved from 0.00041 to 0.00034, saving model to tmp\ckeckpointer.ckpt
# Epoch 9/50
# 98/98 [==============================] - 4s 32ms/step - loss: 8.3867e-05 - mse: 1.6773e-04 - val_loss: 4.8379e-04 - val_mse: 9.6757e-04
#
# Epoch 00009: val_loss did not improve from 0.00034
# Epoch 10/50
# 98/98 [==============================] - 4s 34ms/step - loss: 6.6658e-05 - mse: 1.3332e-04 - val_loss: 7.2878e-04 - val_mse: 0.0015
#
# Epoch 00010: val_loss did not improve from 0.00034
# Epoch 11/50
# 98/98 [==============================] - 4s 35ms/step - loss: 7.4095e-05 - mse: 1.4819e-04 - val_loss: 5.7052e-04 - val_mse: 0.0011
#
# Epoch 00011: val_loss did not improve from 0.00034
# Epoch 12/50
# 98/98 [==============================] - 3s 30ms/step - loss: 5.7385e-05 - mse: 1.1477e-04 - val_loss: 5.4275e-04 - val_mse: 0.0011
#
# Epoch 00012: val_loss did not improve from 0.00034
# Epoch 13/50
# 98/98 [==============================] - 3s 29ms/step - loss: 5.6707e-05 - mse: 1.1341e-04 - val_loss: 6.1287e-04 - val_mse: 0.0012
#
# Epoch 00013: val_loss did not improve from 0.00034
# Epoch 14/50
# 98/98 [==============================] - 4s 34ms/step - loss: 5.8767e-05 - mse: 1.1753e-04 - val_loss: 6.9736e-04 - val_mse: 0.0014
#
# Epoch 00014: val_loss did not improve from 0.00034
# Epoch 15/50
# 98/98 [==============================] - 3s 30ms/step - loss: 7.0355e-05 - mse: 1.4071e-04 - val_loss: 0.0016 - val_mse: 0.0032
#
# Epoch 00015: val_loss did not improve from 0.00034
# Epoch 16/50
# 98/98 [==============================] - 3s 30ms/step - loss: 5.8274e-05 - mse: 1.1655e-04 - val_loss: 4.5094e-04 - val_mse: 9.0187e-04
#
# Epoch 00016: val_loss did not improve from 0.00034
# Epoch 17/50
# 98/98 [==============================] - 3s 32ms/step - loss: 5.0948e-05 - mse: 1.0190e-04 - val_loss: 5.3206e-04 - val_mse: 0.0011
#
# Epoch 00017: val_loss did not improve from 0.00034
# Epoch 18/50
# 98/98 [==============================] - 4s 34ms/step - loss: 5.7433e-05 - mse: 1.1487e-04 - val_loss: 1.8591e-04 - val_mse: 3.7182e-04
#
# Epoch 00018: val_loss improved from 0.00034 to 0.00019, saving model to tmp\ckeckpointer.ckpt
# Epoch 19/50
# 98/98 [==============================] - 3s 31ms/step - loss: 6.2191e-05 - mse: 1.2438e-04 - val_loss: 2.9858e-04 - val_mse: 5.9716e-04
#
# Epoch 00019: val_loss did not improve from 0.00019
# Epoch 20/50
# 98/98 [==============================] - 4s 33ms/step - loss: 5.2043e-05 - mse: 1.0409e-04 - val_loss: 3.8085e-04 - val_mse: 7.6169e-04
#
# Epoch 00020: val_loss did not improve from 0.00019
# Epoch 21/50
# 98/98 [==============================] - 3s 31ms/step - loss: 4.9359e-05 - mse: 9.8717e-05 - val_loss: 5.3692e-04 - val_mse: 0.0011
#
# Epoch 00021: val_loss did not improve from 0.00019
# Epoch 22/50
# 98/98 [==============================] - 3s 33ms/step - loss: 4.9836e-05 - mse: 9.9671e-05 - val_loss: 7.6974e-04 - val_mse: 0.0015
#
# Epoch 00022: val_loss did not improve from 0.00019
# Epoch 23/50
# 98/98 [==============================] - 3s 29ms/step - loss: 5.1878e-05 - mse: 1.0376e-04 - val_loss: 2.2195e-04 - val_mse: 4.4390e-04
#
# Epoch 00023: val_loss did not improve from 0.00019
# Epoch 24/50
# 98/98 [==============================] - 4s 33ms/step - loss: 5.0725e-05 - mse: 1.0145e-04 - val_loss: 3.0015e-04 - val_mse: 6.0031e-04 loss: 5.1061e-05 - mse: 1.0212e
#
# Epoch 00024: val_loss did not improve from 0.00019
# Epoch 25/50
# 98/98 [==============================] - 3s 32ms/step - loss: 4.8826e-05 - mse: 9.7653e-05 - val_loss: 3.7939e-04 - val_mse: 7.5879e-04
#
# Epoch 00025: val_loss did not improve from 0.00019
# Epoch 26/50
# 98/98 [==============================] - 3s 32ms/step - loss: 4.8253e-05 - mse: 9.6505e-05 - val_loss: 1.7012e-04 - val_mse: 3.4023e-04
#
# Epoch 00026: val_loss improved from 0.00019 to 0.00017, saving model to tmp\ckeckpointer.ckpt
# Epoch 27/50
# 98/98 [==============================] - 3s 32ms/step - loss: 5.5460e-05 - mse: 1.1092e-04 - val_loss: 1.8269e-04 - val_mse: 3.6538e-04
#
# Epoch 00027: val_loss did not improve from 0.00017
# Epoch 28/50
# 98/98 [==============================] - 4s 35ms/step - loss: 5.0351e-05 - mse: 1.0070e-04 - val_loss: 3.8223e-04 - val_mse: 7.6446e-04
#
# Epoch 00028: val_loss did not improve from 0.00017
# Epoch 29/50
# 98/98 [==============================] - 3s 31ms/step - loss: 4.8540e-05 - mse: 9.7079e-05 - val_loss: 5.0226e-04 - val_mse: 0.0010
#
# Epoch 00029: val_loss did not improve from 0.00017
# Epoch 30/50
# 98/98 [==============================] - 4s 34ms/step - loss: 5.5792e-05 - mse: 1.1158e-04 - val_loss: 1.3436e-04 - val_mse: 2.6873e-04
#
# Epoch 00030: val_loss improved from 0.00017 to 0.00013, saving model to tmp\ckeckpointer.ckpt
# Epoch 31/50
# 98/98 [==============================] - 3s 29ms/step - loss: 6.2557e-05 - mse: 1.2511e-04 - val_loss: 1.6178e-04 - val_mse: 3.2357e-04
#
# Epoch 00031: val_loss did not improve from 0.00013
# Epoch 32/50
# 98/98 [==============================] - 3s 33ms/step - loss: 6.3770e-05 - mse: 1.2754e-04 - val_loss: 0.0012 - val_mse: 0.0023
#
# Epoch 00032: val_loss did not improve from 0.00013
# Epoch 33/50
# 98/98 [==============================] - 3s 30ms/step - loss: 5.5598e-05 - mse: 1.1120e-04 - val_loss: 4.3668e-04 - val_mse: 8.7336e-04
#
# Epoch 00033: val_loss did not improve from 0.00013
# Epoch 34/50
# 98/98 [==============================] - 3s 32ms/step - loss: 6.1553e-05 - mse: 1.2311e-04 - val_loss: 1.5386e-04 - val_mse: 3.0771e-04
#
# Epoch 00034: val_loss did not improve from 0.00013
# Epoch 35/50
# 98/98 [==============================] - 3s 31ms/step - loss: 5.2788e-05 - mse: 1.0558e-04 - val_loss: 4.0759e-04 - val_mse: 8.1517e-04
#
# Epoch 00035: val_loss did not improve from 0.00013
# Epoch 36/50
# 98/98 [==============================] - 3s 30ms/step - loss: 5.6959e-05 - mse: 1.1392e-04 - val_loss: 4.3774e-04 - val_mse: 8.7549e-04
#
# Epoch 00036: val_loss did not improve from 0.00013
# Epoch 37/50
# 98/98 [==============================] - 3s 32ms/step - loss: 4.6410e-05 - mse: 9.2820e-05 - val_loss: 4.7400e-04 - val_mse: 9.4800e-04
#
# Epoch 00037: val_loss did not improve from 0.00013
# Epoch 38/50
# 98/98 [==============================] - 3s 30ms/step - loss: 4.5851e-05 - mse: 9.1702e-05 - val_loss: 4.7478e-04 - val_mse: 9.4955e-04
#
# Epoch 00038: val_loss did not improve from 0.00013
# Epoch 39/50
# 98/98 [==============================] - 3s 29ms/step - loss: 5.0834e-05 - mse: 1.0167e-04 - val_loss: 2.4206e-04 - val_mse: 4.8411e-04
#
# Epoch 00039: val_loss did not improve from 0.00013
# Epoch 40/50
# 98/98 [==============================] - 3s 31ms/step - loss: 5.2786e-05 - mse: 1.0557e-04 - val_loss: 3.9020e-04 - val_mse: 7.8040e-04
#
# Epoch 00040: val_loss did not improve from 0.00013

# %%
pred = model.predict(test_data)

# %%
rescaled_y_test = scaler1.inverse_transform(np.array(y_test).reshape(-1, 1))
rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))

# %%
# 평가지표 함수
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

def confirm_result(y_test, y_pred):
    MAE = mean_absolute_error(y_test, y_pred)
    RMSE = np.sqrt(mean_squared_error(y_test, y_pred))
    MSLE = mean_squared_log_error(y_test, y_pred)
    RMSLE = np.sqrt(mean_squared_log_error(y_test, y_pred))
    R2 = r2_score(y_test, y_pred)
        
    pd.options.display.float_format = '{:.5f}'.format
    Result = pd.DataFrame(data=[MAE,RMSE, RMSLE, R2],
                            index = ['MAE','RMSE', 'RMSLE', 'R2'],
                            columns=['Results'])
    return Result

# %%
confirm_result(rescaled_y_test[20:], rescaled_pred)
# Out:
#          Results
# MAE   3362.06910
# RMSE  4457.73061
# RMSLE    0.04175
# R2       0.95264
